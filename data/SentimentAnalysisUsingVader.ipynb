# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
import warnings
warnings.filterwarnings('ignore')

# Ensure the VADER lexicon is downloaded (only needs to be done once)
nltk.download('vader_lexicon')

# Load the cleaned CSV file into a DataFrame
df = pd.read_csv('cleaned_restaurant_reviews.csv')

# Initialize VADER sentiment intensity analyzer
analyzer = SentimentIntensityAnalyzer()

# Define a function to get the compound sentiment score
def get_vader_sentiment(text):
    scores = analyzer.polarity_scores(text)
    # Return the compound sentiment score
    return scores['compound']

# Apply the function to the 'Review Text' column
df['sentiment_score'] = df['cleaned_review'].apply(get_vader_sentiment)

# Classify the sentiment as positive, negative, or neutral
def classify_sentiment(score):
    if score > 0.05:  # Positive sentiment threshold
        return 'Positive'
    elif score < -0.05:  # Negative sentiment threshold
        return 'Negative'
    else:
        return 'Neutral'

# Apply the classification function
df['sentiment'] = df['sentiment_score'].apply(classify_sentiment)

# Save the updated DataFrame into a new CSV file (optional)
df.to_csv('vader_sentiment_analyzed_reviews.csv', index=False)

# Preview the updated DataFrame
df[['cleaned_review', 'cleaned_rating','sentiment_score', 'sentiment']].head(20)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\15735\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                        cleaned_review  cleaned_rating  \
# 0   we got this delivered to our house in washingt...             4.7
# 1   100100 hands down the best bbq in the country ...             4.7
# 2   franklin barbecue truly lives up to the hype t...             4.7
# 3   going to franklin takes a level of commitment ...             4.7
# 4   without a doubt the greatest of all time\n\nbe...             4.7
# 5   i cannot share enough good things about this a...             4.7
# 6   we came to austin for a quick girls weekend an...             4.7
# 7   we stayed here for a girls trip and it was abs...             4.7
# 8   we love staying at hotel san jose immaculate v...             4.7
# 9   10000010 place couldnt recommend enough i book...             4.7
# 10  ate dinner here the other night got the stubbs...             4.3
# 11  hey so we stopped at stubbs barbq and it was t...             4.3
# 12  i went for lunch alone it was not crowded arou...             4.3
# 13  parking was difficult to find along the road a...             4.3
# 14  the place is laid back almost like a time warp...             4.3
# 15  delicious food friendly service massive quanti...             4.6
# 16  loved the atmosphere as it was in an old house...             4.6
# 17  i was visiting austin with my friend and we we...             4.6
# 18  went for two different mixers and the portions...             4.6
# 19  weve been to their avery location but never th...             4.6
#
#     sentiment_score sentiment
# 0            0.9099  Positive
# 1            0.9796  Positive
# 2            0.9853  Positive
# 3            0.6902  Positive
# 4            0.3903  Positive
# 5            0.9954  Positive
# 6            0.9972  Positive
# 7            0.9790  Positive
# 8            0.9709  Positive
# 9            0.9867  Positive
# 10           0.6903  Positive
# 11           0.9676  Positive
# 12           0.9494  Positive
# 13           0.5327  Positive
# 14           0.8921  Positive
# 15           0.8934  Positive
# 16           0.8962  Positive
# 17           0.9916  Positive
# 18           0.9545  Positive
# 19           0.9810  Positive
